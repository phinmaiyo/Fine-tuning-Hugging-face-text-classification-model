# %% [markdown]
# <a href="https://colab.research.google.com/github/phinmaiyo/Fine-tuning-Hugging-face-text-classification-model/blob/main/Twitter_Bert__sentiment_analysis_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis with Hugging Face

# %% [markdown]
# Hugging Face is an open-source and platform provider of machine learning technologies. You can use install their package to access some interesting pre-built models to use them directly or to fine-tune (retrain it on your dataset leveraging the prior knowledge coming with the first training), then host your trained models on the platform, so that you may use them later on other devices and apps.
#
# Please, [go to the website and sign-in](https://huggingface.co/) to access all the features of the platform.
#
# [Read more about Text classification with Hugging Face](https://huggingface.co/tasks/text-classification)
#
# The Hugging face models are Deep Learning based, so will need a lot of computational GPU power to train them. Please use [Colab](https://colab.research.google.com/) to do it, or your other GPU cloud provider, or a local machine having NVIDIA GPU.

# %% [markdown]
# ## Application of Hugging Face Text classification model Fune-tuning

# %% [markdown]
# Find below a simple example, with just `5 epochs of fine-tuning`.
#
# Read more about the fine-tuning concept : [here](https://deeplizard.com/learn/video/5T-iXNNiwIs#:~:text=Fine%2Dtuning%20is%20a%20way,perform%20a%20second%20similar%20task.)

# %% [markdown]
# INSTALLATIONS

# %%
# Install required dependencies
# !pip install -q datasets transformers huggingface_hub accelerate -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 39.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 34.9 MB/s eta 0:00:00

# %%
# load libraries
import os
import pandas as pd
import numpy as np
import re

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter

# Google drive
from google.colab import drive

# Deep learning
import torch
import torch.nn as nn

# Scikit-Learn
from sklearn.model_selection import train_test_split

# Dataset
from datasets import load_dataset, load_metric
from sklearn.metrics import accuracy_score

# Transformers
from transformers import AutoTokenizer, TrainingArguments, Trainer, AutoModelForSequenceClassification, DataCollatorWithPadding
from transformers import BertTokenizer, BertModel
# Balance classes
from sklearn.utils.class_weight import compute_class_weight

# huggingface
from huggingface_hub import notebook_login
from huggingface_hub import create_repo

# filter warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# check the availability of GPU
torch.cuda.is_available()
# Out:
# True

# %%
# Disable W&B
os.environ["WANDB_DISABLED"] = "true"

# %%
# mount google drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Access Google Drive
# %cd /content/drive/MyDrive/"Colab Notebooks"/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/data

# %%
# Load the datasets and display some values
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Test.csv')
# A way to eliminate rows containing NaN values
#df = df[~df.isna().any(axis=1)]

# %% [markdown]
# ## DATA UNDERSTANDING AND EDA

# %%
# load the first 5 rows of train dataset
train.head()
# Out:
#    tweet_id                                          safe_text  label  \
# 0  CL1KWCMY  Me &amp; The Big Homie meanboy3000 #MEANBOY #M...    0.0
# 1  E3303EME  I'm 100% thinking of devoting my career to pro...    1.0
# 2  M4IVFSMS  #whatcausesautism VACCINES, DO NOT VACCINATE Y...   -1.0
# 3  1DR6ROZ4  I mean if they immunize my kid with something ...   -1.0
# 4  J77ENIIE  Thanks to <user> Catch me performing at La Nui...    0.0
#
#    agreement
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0

# %%
# load the first 5 rows of the test dataset
test.head()
# Out:
#    tweet_id                                          safe_text
# 0  00BHHHP1  <user> <user> ... &amp; 4 a vaccine given 2 he...
# 1  00UNMD0E  Students starting school without whooping coug...
# 2  01AXPTJF  I'm kinda over every ep of <user> being "rippe...
# 3  01HOEQJW  How many innocent children die for lack of vac...
# 4  01JUKMAO  CDC eyeing bird flu vaccine for humans, though...

# %%
# check the number of rows and columns from train and test datasets
print(train.shape, test.shape)
# Out:
# (10001, 4) (5177, 2)

# %%
# get more info on train dataset
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   10001 non-null  object
#  1   safe_text  10001 non-null  object
#  2   label      10000 non-null  float64
#  3   agreement  9999 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 312.7+ KB

# %% [markdown]
# There are a few null values on label and agreement columns

# %%
# get more info on test dataset
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5177 entries, 0 to 5176
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   5177 non-null   object
#  1   safe_text  5176 non-null   object
# dtypes: object(2)
# memory usage: 81.0+ KB

# %%
#check for null values
train.isna().sum()
# Out:
# tweet_id     0
# safe_text    0
# label        1
# agreement    2
# dtype: int64

# %%
#check for null values
test.isna().sum()
# Out:
# tweet_id     0
# safe_text    1
# dtype: int64

# %%
# check for duplicates
train.duplicated().sum()
# Out:
# 0

# %%
# check for duplicates
test.duplicated().sum()
# Out:
# 0

# %%
# check for distribution of labels
train['label'].value_counts()
# Out:
#  0.000000    4908
#  1.000000    4053
# -1.000000    1038
#  0.666667       1
# Name: label, dtype: int64

# %%
# check for inconsistencies in text column
train['safe_text'].sample(10)
# Out:
# 7683    PREVENT #CervicalCancer! Get your kids #vaccin...
# 9069    My shmoopie baby nephew smiled through the pai...
# 8526    Meet me at #EscapeGentlemensClub Right Now‼️‼️...
# 4384    UMF madhatterdc #mmr #edmlife #edm #ultra2014 ...
# 4141    Vaccinate your children. #vaccinate #disneylan...
# 6814    2014, an outbreak of measles 644 were Amish; 3...
# 7174    My child has a shitty immune system and relies...
# 8517    Arizona monitoring hundreds for measles linked...
# 2639    Why are noninfectious ppl being put into quara...
# 5131    "<user> Las Vegas confirms three new cases of ...
# Name: safe_text, dtype: object

# %% [markdown]
# There are excessive spaces in the safe text column which could affect the analysis and the performance of the model.

# %% [markdown]
# ## Data Cleaning

# %%
# create function to remove special characters, mentions and URLs
def clean_text(text):
  # remove URLs
  text=re.sub(r'http\S+', '', text)
  # remove mentions
  text=re.sub(r'<user>', '', text)
  text=re.sub(r'<url>', '', text)
  # remove special characters
  text=re.sub(r'[^a-zA-Z\s]', '', text)
  return text
# apply fuction to safe_text column
train['safe_text']= train['safe_text'].apply(clean_text)

# %%
# validate changes
train['safe_text'].sample(10)
# Out:
# 1200    If you dont vaccinate your kid I hope you get ...
# 2673     what do you say to the science that the vacci...
# 4978    Please VaccinateYourKids Conserving heard immu...
# 6197    Austerity is not a Vaccine to Crisis It is a P...
# 6439      Trying not to pass out on bart or catch measles
# 9934         not in childhood vaccines The claim is th...
# 6300     its so ridiculous People think that the vacci...
# 9715    Parenting privileges should be taken away for ...
# 668     Threekid vaccine catchup appt Yay  Im overshar...
# 2886     So what if the kid wont get autism from the v...
# Name: safe_text, dtype: object

# %% [markdown]
# ## Remove White Spaces

# %%
# function to remove white spaces
def remove_white_spaces (text):
  # Remove leading and trailing white spaces
  cleaned_text = re.sub(r'^\s+|\s+?$', '', text, flags=re.MULTILINE)
  return cleaned_text
# Apply function
train['safe_text'] = train['safe_text'].apply(remove_white_spaces)

# %%
# validate changes
train['safe_text'].sample(10)
# Out:
# 3639    This is scary  How many people arent vaccinati...
# 3032    If you think anthropogenic climate change isnt...
# 8925    RE FUCKING TWEET  If you think vaccines give y...
# 710     A baby was born on the J train this morning Ca...
# 8108    May child was dx  the CDC already knew the ris...
# 9037    Every  seconds a child dies from a vaccineprev...
# 6770                                      Measles at HBHS
# 814     oh did we know to ask until after   I didnt   ...
# 3205    People who dont believe in climate change peop...
# 8666    noshotsnoschool RT  The science is clear The e...
# Name: safe_text, dtype: object

# %% [markdown]
# ## Drop missing values

# %%
# Drop missing values in train
train.dropna(inplace=True)

# %%
train.isna().sum()
# Out:
# tweet_id     0
# safe_text    0
# label        0
# agreement    0
# dtype: int64

# %%
# Drop missing values in test
test.dropna(inplace=True)

# %%
test.isna().sum()
# Out:
# tweet_id     0
# safe_text    0
# dtype: int64

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# ## Visualize common words in positive, negative and neutral classes

# %%
# Sample data for three sentiment classes
positive_text = train[train['label'] == 1]['safe_text']
negative_text = train[train['label'] == -1]['safe_text']
neutral_text = train[train['label'] == 0]['safe_text']

# Tokenize and preprocess the text if needed
# Count word frequencies for each sentiment class
positive_word_freq = Counter(" ".join(positive_text).split())
negative_word_freq = Counter(" ".join(negative_text).split())
neutral_word_freq = Counter(" ".join(neutral_text).split())

# Create word clouds
wordcloud_positive = WordCloud(width=800, height=400).generate_from_frequencies(positive_word_freq)
wordcloud_negative = WordCloud(width=800, height=400).generate_from_frequencies(negative_word_freq)
wordcloud_neutral = WordCloud(width=800, height=400).generate_from_frequencies(neutral_word_freq)

# Plot the word clouds
plt.figure(figsize=(7, 14))

plt.subplot(311)  # Positive
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Words')
plt.axis('off')

plt.subplot(312)  # Negative
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Words')
plt.axis('off')

plt.subplot(313)  # Neutral
plt.imshow(wordcloud_neutral, interpolation='bilinear')
plt.title('Neutral Words')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Distribution of sentiment labels

# %%
# Count the occurrences of each sentiment label
sentiment_counts = train['label'].value_counts()

# Create a bar plot to visualize the distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values)
plt.title("Distribution of Sentiment Labels")
plt.xlabel("Sentiment Label")
plt.ylabel("Count")

# Customize the labels if needed
plt.xticks(rotation=360)  # Rotate x-axis labels for readability

# Show the plot
plt.show()

# %% [markdown]
# The plot visually represents the distribution of sentiment labels.
#
#
# *  Netral(0.0) represented by the yellow bar has the highest occurences of 4908.
# *  Positive(1.0) represented by the green bar has occurences of 4053 occurences.
# *  Negative(-1.0) represented by the blue bar has 1038 occurences.
# The neutral and positive sentiments are more prevalent compared to negative sentiments.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# I manually split the training set to have a training subset ( a dataset the model will learn on), and an evaluation subset ( a dataset the model with use to compute metric scores to help use to avoid some training problems like [the overfitting](https://www.ibm.com/cloud/learn/overfitting) one ).
#
# There are multiple ways to do split the dataset. You'll see two commented line showing you another one.

# %%
# Split the train data => {train, eval}
train, eval = train_test_split(train, test_size=0.2, random_state=42, stratify=train['label'])

# %%
train.head()
# Out:
#       tweet_id                                          safe_text  label  \
# 9305  YMRMEDME             Mickeys Measles has gone international    0.0
# 3907  5GV8NEZS  S NEW Extends exemption from charitable immuni...    0.0
# 795   EI10PS46  your ignorance on vaccines isnt just dangerous...    1.0
# 5793  OM26E6DG  Pakistan partly suspends polio vaccination pro...    0.0
# 3431  NBBY86FX                In other news Ive gone up like  mmr    0.0
#
#       agreement
# 9305   1.000000
# 3907   1.000000
# 795    0.666667
# 5793   1.000000
# 3431   1.000000

# %%
eval.head()
# Out:
#       tweet_id                                          safe_text  label  \
# 6571  R7JPIFN7  Childrens Museum of Houston to Offer Free Vacc...    1.0
# 1754  2DD250VN  no I was properly immunized prior to the perfo...    1.0
# 3325  ESEVBTFN  thx for posting vaccinations are imperative A ...    1.0
# 1485  S17ZU0LC  This Baby Is Exactly Why Everyone Needs To Vac...    1.0
# 4175  IIN5D33V  Meeting tonight pm in room  of the student cen...    1.0
#
#       agreement
# 6571   1.000000
# 1754   1.000000
# 3325   1.000000
# 1485   0.666667
# 4175   1.000000

# %%
print(f"new dataframe shapes: train is {train.shape}, eval is {eval.shape}")
# Out:
# new dataframe shapes: train is (7999, 4), eval is (2000, 4)

# %%
# Calculate class weights based on the distribution in the training set
class_weights = compute_class_weight("balanced", classes=np.unique(train['label']), y=train['label'])
# Convert to a dictionary for easier use
class_weights_dict = dict(zip(np.unique(train['label']), class_weights))

# %%
# Save splitted subsets
train.to_csv("train_subset.csv", index=False)
eval.to_csv("eval_subset.csv", index=False)

# %%
# load the dataset
dataset = load_dataset('csv',
                        data_files={'train': 'train_subset.csv',
                        'eval': 'eval_subset.csv'}, encoding = "ISO-8859-1")
# Out:
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]

# %%
# load pretrained model from hugging face
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# preparing our data for training a machine learning model by converting text data into tokenized format and ensuring the labels are in a numerical format suitable for modeling.

# %%
def transform_labels(label):

    label = label['label']
    num = 0
    if label == -1: #'Negative'
        num = 0
    elif label == 0: #'Neutral'
        num = 1
    elif label == 1: #'Positive'
        num = 2

    return {'labels': num}

def tokenize_data(example):
    return tokenizer(example['safe_text'], padding='max_length', truncation=True, max_length=128, return_tensors='pt')

# Change the tweets to tokens that the models can exploit
dataset = dataset.map(tokenize_data, batched=True)

# Transform	labels and remove the useless columns
remove_columns = ['tweet_id', 'label', 'safe_text', 'agreement']
dataset = dataset.map(transform_labels, remove_columns=remove_columns)
# Out:
# Map:   0%|          | 0/7999 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7999 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 7999
#     })
#     eval: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 2000
#     })
# })

# %% [markdown]
#  DatasetDict object containing training and evaluation datasets, each with features like 'input_ids', 'attention_mask', and 'labels'.
#
# * input_ids: These are tokenized input sequences converted to IDs, ready for model input.
#
# * attention_mask: This is a binary mask that indicates which tokens the model should pay attention to (usually 1 for tokens, 0 for padding).
#
# * labels: These are the target labels for the text classification task.

# %%
# Loading a pretrain model while specifying the number of labels in our dataset for fine-tuning
model = AutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# instantiate the train and validation sets
train_dataset = dataset['train'].shuffle(seed=10)
eval_dataset = dataset['eval'].shuffle(seed=10)

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# adding custom training options or parameters to the TrainingArguments used to initialize the trainer

training_args = TrainingArguments(
    output_dir="bert_fine_tuned_sentiment",  # Directory where model checkpoints and logs will be saved
    num_train_epochs=5,  # Number of training epochs
    per_device_train_batch_size=8,  # Batch size per GPU or CPU
    per_device_eval_batch_size=8,  # Batch size for evaluation
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
    save_strategy="epoch",  # save at the end of each training epoch
    load_best_model_at_end=True,  # Load the best model at the end of training
    push_to_hub=True,# Upload the model to the Hugging Face model hub
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
# perform text tokenization, padding, and formatting of train data so that it can be efficiently processed by deep learning models
data_collator = DataCollatorWithPadding(tokenizer=tokenizer,padding ='max_length', max_length=128, return_tensors='pt')

# %%
# define Custom Trainer and modify loss function
class CustomTrainer(Trainer):
  def compute_loss(self, model, inputs, return_outputs= False):
    labels= inputs.get("labels")
    # forward pass
    outputs = model(**inputs)
    logits = outputs.get('logits')
    # Check if logits or labels are None
    if logits is None or labels is None:
        raise ValueError("Logits or labels is None.")
    # compute custom loss
    loss_function = nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32).to(model.device))
    loss = loss_function(logits.view(-1, self.model.config.num_labels), labels.view(-1))
    return(loss, outputs) if return_outputs else loss

# %%
# compute evaluation metrics
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = accuracy_score(y_true=labels, y_pred=predictions)
    return {"accuracy": acc}

# %%
# instantiate the trainer for trainer
custom_trainer = CustomTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics
)

# %%
# Train the model
custom_trainer.train()
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 19:17, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.863900</td>
#       <td>0.839653</td>
#       <td>0.741500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.697300</td>
#       <td>0.702543</td>
#       <td>0.739000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.470600</td>
#       <td>0.897174</td>
#       <td>0.749000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.327900</td>
#       <td>1.352480</td>
#       <td>0.763000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.206600</td>
#       <td>1.561208</td>
#       <td>0.757000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=5000, training_loss=0.5259780090332031, metrics={'train_runtime': 1161.1143, 'train_samples_per_second': 34.445, 'train_steps_per_second': 4.306, 'total_flos': 2630805285507840.0, 'train_loss': 0.5259780090332031, 'epoch': 5.0})

# %%
# Sample data
Epochs = [1, 2, 3, 4, 5]
Training_loss = [0.789300	, 0.619600, 0.424400, 0.254200 , 0.175300]
Validation_loss = [0.789459, 0.698257, 1.009773, 1.524390, 1.694032]
Accuracy = [0.756000, 0.760000, 0.752500, 0.757000, 0.753000]


# Create a single plot for all metrics
plt.figure(figsize=(10, 6))
plt.title("Training and Validation Metrics Over Epochs")
plt.xlabel("Epochs")
plt.grid()

# Plot Training Loss
plt.plot(Epochs, Training_loss, label='Training Loss', marker='o')

# Plot Validation Loss
plt.plot(Epochs, Validation_loss, label='Validation Loss', marker='o')

# Plot Accuracy
plt.plot(Epochs, Accuracy, label='Accuracy', marker='o', linestyle='--', color='green')

plt.legend()
plt.show()

# %% [markdown]
# ## From the visualization the model starts to overfit after the second epoch, where the validation loss starts to plateau or increase while the training loss continues to decrease.

# %%
# Launch the final evaluation
custom_trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:14]
#     </div>
# {'eval_loss': 0.7025425434112549,
#  'eval_accuracy': 0.739,
#  'eval_runtime': 15.0559,
#  'eval_samples_per_second': 132.838,
#  'eval_steps_per_second': 16.605,
#  'epoch': 5.0}

# %% [markdown]
# ## The model has an accuracy of 73.9 percent with an evaluation loss of 70.25 percent.

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# push the model and tokenizer to hugging face
custom_trainer.push_to_hub
tokenizer.push_to_hub( "bert_fine_tuned_sentiment")
# Out:
# CommitInfo(commit_url='https://huggingface.co/phinm/bert_fine_tuned_sentiment/commit/97e6b02b5fdca778bc25002c775b8b3b0d157ae8', commit_message='Upload tokenizer', commit_description='', oid='97e6b02b5fdca778bc25002c775b8b3b0d157ae8', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# You may also upload the model on the Hugging Face Platform... [Read more](https://huggingface.co/docs/hub/models-uploading)

# %% [markdown]
# This notebook is inspired by an article: [Fine-Tuning Bert for Tweets Classification ft. Hugging Face](https://medium.com/mlearning-ai/fine-tuning-bert-for-tweets-classification-ft-hugging-face-8afebadd5dbf)

# %% [markdown]
# Do not hesitaite to read more and to ask questions, the Learning is a lifelong activity.
